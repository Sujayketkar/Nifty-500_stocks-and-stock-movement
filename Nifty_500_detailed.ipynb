# %%
#Import the Libraries
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px


from warnings import filterwarnings
filterwarnings('ignore')

# %%
df =pd.read_csv('ind_nifty500list.csv')
df_all = pd.read_csv('All_listed_Mar2023.csv')
df=df.merge(df_all, on='Symbol')
df.sort_values(by='Market capitalization as on March 31, 2023\n(Rs in Lakhs)', ascending=False)
df.rename(columns={'Market capitalization as on March 31, 2023\n(Rs in Lakhs)':'Mcap_Mar23'}, inplace=True)
df['Mcap_Mar23']=df['Mcap_Mar23'].astype('float')
df=df.reset_index()
df=df.drop(columns='index')
df=df.drop(columns='Sr. No.')

# %%
df
# Out:
#               Company Name_x                    Industry      Symbol Series  \
# 0           360 ONE WAM Ltd.          Financial Services      360ONE     EQ
# 1              3M India Ltd.                 Diversified     3MINDIA     EQ
# 2             ABB India Ltd.               Capital Goods         ABB     EQ
# 3                   ACC Ltd.      Construction Materials         ACC     EQ
# 4       AIA Engineering Ltd.               Capital Goods      AIAENG     EQ
# ..                       ...                         ...         ...    ...
# 481  Zensar Technolgies Ltd.      Information Technology  ZENSARTECH     EQ
# 482              Zomato Ltd.           Consumer Services      ZOMATO     EQ
# 483  Zydus Lifesciences Ltd.                  Healthcare   ZYDUSLIFE     EQ
# 484      Zydus Wellness Ltd.  Fast Moving Consumer Goods   ZYDUSWELL     EQ
# 485     eClerx Services Ltd.                    Services      ECLERX     EQ
#
# ...

# %%
df_industry=df.groupby(by='Industry').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
df_industry
# Out:
#                              Industry  counts
# 9                  Financial Services      86
# 1                       Capital Goods      56
# 11                         Healthcare      44
# 2                           Chemicals      39
# 0      Automobile and Auto Components      30
# 8          Fast Moving Consumer Goods      29
# 5                   Consumer Durables      29
# 6                   Consumer Services      26
# 12             Information Technology      25
# 15         Oil Gas & Consumable Fuels      17
# 18                           Services      16
# 14                    Metals & Mining      14
# 4              Construction Materials      13
# 3                        Construction      12
# 17                             Realty      11
# 16                              Power      11
# 19                  Telecommunication      10
# 20                           Textiles       7
# 13  Media Entertainment & Publication       6
# ...

# %%
df_Autocomp=df[df['Industry']=='Automobile and Auto Components']

# %%
df_Autocomp
# Out:
#                                        Company Name_x  \
# 33                                  Apollo Tyres Ltd.
# 36                             Asahi India Glass Ltd.
# 49                                    Bajaj Auto Ltd.
# 54                         Balkrishna Industries Ltd.
# 76                                         Bosch Ltd.
# 92                                          Ceat Ltd.
# 113                         Craftsman Automation Ltd.
# 136                                Eicher Motors Ltd.
# 139                       Endurance Technologies Ltd.
# 144                             Exide Industries Ltd.
# 195                                Hero MotoCorp Ltd.
# 241                                     JBM Auto Ltd.
# 247                        Jamna Auto Industries Ltd.
# 286                                          MRF Ltd.
# 291                          Mahindra & Mahindra Ltd.
# 297                          Maruti Suzuki India Ltd.
# ...

# %%
df_Autocomp.dtypes
# Out:
# Company Name_x     object
# Industry           object
# Symbol             object
# Series             object
# ISIN Code          object
# Company Name_y     object
# Mcap_Mar23        float64
# dtype: object

# %%
df_Autocomp.sort_values(by='Mcap_Mar23', ascending=False)
# Out:
#                                        Company Name_x  \
# 297                          Maruti Suzuki India Ltd.
# 291                          Mahindra & Mahindra Ltd.
# 433                                  Tata Motors Ltd.
# 49                                    Bajaj Auto Ltd.
# 136                                Eicher Motors Ltd.
# 76                                         Bosch Ltd.
# 425                            TVS Motor Company Ltd.
# 451                    Tube Investments of India Ltd.
# 195                                Hero MotoCorp Ltd.
# 386          Samvardhana Motherson International Ltd.
# 390                             Schaeffler India Ltd.
# 54                         Balkrishna Industries Ltd.
# 286                                          MRF Ltd.
# 453                                    UNO Minda Ltd.
# 401                  Sona BLW Precision Forgings Ltd.
# 306                  Motherson Sumi Wiring India Ltd.
# ...

# %%
 df_Financial=df[df['Industry']=='Financial Services']

# %%
df_Financial.sort_values(by='Mcap_Mar23', ascending=False)
# Out:
#                       Company Name_x            Industry      Symbol Series  \
# 189                   HDFC Bank Ltd.  Financial Services    HDFCBANK     EQ
# 206                  ICICI Bank Ltd.  Financial Services   ICICIBANK     EQ
# 404              State Bank of India  Financial Services        SBIN     EQ
# 269         Kotak Mahindra Bank Ltd.  Financial Services   KOTAKBANK     EQ
# 50                Bajaj Finance Ltd.  Financial Services  BAJFINANCE     EQ
# ..                               ...                 ...         ...    ...
# 456  Ujjivan Small Finance Bank Ltd.  Financial Services  UJJIVANSFB     EQ
# 268           Kfin Technologies Ltd.  Financial Services    KFINTECH     EQ
# 219  Indiabulls Housing Finance Ltd.  Financial Services  IBULHSGFIN     EQ
# 85                     CSB Bank Ltd.  Financial Services     CSBBANK     EQ
# 232            Infibeam Avenues Ltd.  Financial Services    INFIBEAM     EQ
#
# ...

# %%
df_Healthcare=df[df['Industry']=='Healthcare']

# %%
df_Healthcare=df_Healthcare.sort_values(by='Mcap_Mar23',ascending=False)
df_Healthcare
# Out:
#                                  Company Name_x    Industry      Symbol  \
# 410          Sun Pharmaceutical Industries Ltd.  Healthcare   SUNPHARMA
# 131               Dr. Reddy's Laboratories Ltd.  Healthcare     DRREDDY
# 128                    Divi's Laboratories Ltd.  Healthcare    DIVISLAB
# 103                                  Cipla Ltd.  Healthcare       CIPLA
# 32             Apollo Hospitals Enterprise Ltd.  Healthcare  APOLLOHOSP
# 445                Torrent Pharmaceuticals Ltd.  Healthcare  TORNTPHARM
# 483                     Zydus Lifesciences Ltd.  Healthcare   ZYDUSLIFE
# 300               Max Healthcare Institute Ltd.  Healthcare   MAXHEALTH
# 23                      Alkem Laboratories Ltd.  Healthcare       ALKEM
# 42                        Aurobindo Pharma Ltd.  Healthcare  AUROPHARMA
# 283                                  Lupin Ltd.  Healthcare       LUPIN
# 69                                  Biocon Ltd.  Healthcare      BIOCON
# ...

# %%
df_Services=df[df['Industry']=='Services']

# %%
df_Services
# Out:
#                                  Company Name_x  Industry      Symbol Series  \
# 12   Adani Ports and Special Economic Zone Ltd.  Services  ADANIPORTS     EQ
# 25                      Allcargo Logistics Ltd.  Services    ALLCARGO     EQ
# 72                       Blue Dart Express Ltd.  Services    BLUEDART     EQ
# 111         Container Corporation of India Ltd.  Services      CONCOR     EQ
# 125                              Delhivery Ltd.  Services   DELHIVERY     EQ
# 152                  Firstsource Solutions Ltd.  Services         FSL     EQ
# 158            GMR Airports Infrastructure Ltd.  Services    GMRINFRA     EQ
# 176             Great Eastern Shipping Co. Ltd.  Services      GESHIP     EQ
# 183                   Gujarat Pipavav Port Ltd.  Services        GPPL     EQ
# 237                    InterGlobe Aviation Ltd.  Services      INDIGO     EQ
# 285                                   MMTC Ltd.  Services        MMTC     EQ
# ...

# %%
df.sort
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df.sort
#
# File ~\.conda\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort'
